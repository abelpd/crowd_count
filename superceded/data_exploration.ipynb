# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import pickle as pkl
import os
import cv2

# %%
os.getcwd()
# Out:
# 'C:\\Users\\abelp\\machine_learning\\crowd_count'

# %%
cwd = os.getcwd()

# %%
os.listdir(cwd+ '\\data')
# Out:
# ['count_.csv', 'final_input_aj_1.pkl', 'final_input_aj_2.pkl']

# %%
target = pd.read_csv(cwd + '\\data\\count_.csv', names=['target'])

# %%
target
# Out:
#       target
# 0         29
# 1         30
# 2         35
# 3         31
# 4         26
# ...      ...
# 1995      27
# 1996      27
# 1997      25
# 1998      26
# 1999      26
#
# [2000 rows x 1 columns]

# %%
sns.distplot(target['target'])
plt.show()

# %%
input_ = np.append(pkl.load(open(r'C:\Users\abelp\machine_learning\crowd_count\data\final_input_aj_1.pkl', 'rb')), 
                   pkl.load(open(r'C:\Users\abelp\machine_learning\crowd_count\data\final_input_aj_2.pkl', 'rb')), axis=0)

# %%
input_.shape
# Out:
# (2000, 480, 640)

# %%
print (target.iloc[10])
plt.imshow(input_[10])
plt.show()
# Out:
# target    37
# Name: 10, dtype: int64

# %%
print (target.iloc[255])
plt.imshow(input_[255])
plt.show()
# Out:
# target    18
# Name: 255, dtype: int64

# %%
print (target.iloc[350])
plt.imshow(input_[350])
plt.show()
# Out:
# target    36
# Name: 350, dtype: int64
