# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
target = np.load(r'C:\Users\abels\Desktop\crowd_count\crowd-counting\labels\labels.npy')

# %%
images = np.load(r'C:\Users\abels\Desktop\crowd_count\crowd-counting\frames\np_frames\images.npy')

# %%
test_target = pd.read_csv('count_.csv', names=['test'])

# %%
test_target = np.array(test_target['test'])

# %%
images.shape
# Out:
# (2000, 480, 640, 3)

# %%
target.shape
# Out:
# (2000, 1)

# %%
print (target[0])
print (test_target[0])
plt.imshow(images[0])
plt.show()
# Out:
# [35]
# 29

# %%
print (target[1])
print (test_target[1])
plt.imshow(images[1])
plt.show()
# Out:
# [41]
# 30

# %%
print (target[2])
print (test_target[2])
plt.imshow(images[2])
plt.show()
# Out:
# [41]
# 35

# %%
print (target[100])
plt.imshow(images[100])
plt.show()
# Out:
# [28]

# %%
print (target[10])
plt.imshow(images[10])
plt.show()
# Out:
# [16]

# %%
print (target[1])
plt.imshow(images[1])
plt.show()
# Out:
# [41]

# %%
print (target[33])
plt.imshow(images[33])
plt.show()
# Out:
# [19]

# %%
print (target[333])
plt.imshow(images[333])
plt.show()
# Out:
# [36]

# %%
print (target[323])
plt.imshow(images[323])
plt.show()
# Out:
# [34]

# %%
print (target[0])
plt.imshow(images[0])
plt.show()
# Out:
# [35]

# %%
print (target[1])
plt.imshow(images[1])
plt.show()
# Out:
# [41]
