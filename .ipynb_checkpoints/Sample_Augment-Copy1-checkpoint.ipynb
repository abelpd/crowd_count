# %%
from skimage.color import rgb2hsv
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import pickle as pkl
import cv2
import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %%
cwd = os.getcwd()

# %%
target = pd.read_csv(cwd + '\\data\\count_.csv', names=['target'])

# %%
target.head()
# Out:
#    target
# 0      29
# 1      30
# 2      35
# 3      31
# 4      26

# %%
input_ = np.append(pkl.load(open(r'C:\Users\abelp\machine_learning\crowd_count\data\final_input_aj_1.pkl', 'rb')),
                  pkl.load(open(r'C:\Users\abelp\machine_learning\crowd_count\data\final_input_aj_2.pkl', 'rb')), axis=0)

# %%
model_location = 'C:\\Users\\abelp\\machine_learning\\crowd_count\\models\\'

# %%
plt.imshow(input_[0])
plt.show()

# %%
input_.shape
# Out:
# (2000, 480, 640)

# %%
input_ = np.expand_dims(input_, axis=3)

# %%
input_.shape
# Out:
# (2000, 480, 640, 1)

# %%
datagen = ImageDataGenerator(
        horizontal_flip=True,
        vertical_flip=True,
        fill_mode='nearest')

# %%
datagen

# %%
for x in range(0,2000):
    datagen = ImageDataGenerator(
        horizontal_flip=True,
        vertical_flip=True,
        fill_mode='nearest')
    datagen.fit(input_[x*1:x*1+1])
    generated_images_ = datagen.flow(input_[x*1:x*1+1], y=target[x*1:x*1+1], batch_size=1)
    input_ = np.append(input_, generated_images_[0][0].astype(np.uint8), axis=0)
    target = np.append(target, generated_images_[0][1])

# %%
len(input_)
# Out:
# 4000

# %%
target.shape
# Out:
# (4000,)

# %%
input_.shape
# Out:
# TensorShape([4000, 480, 640])

# %%
input_ = tf.squeeze(input_)

# %%
plt.imshow((input_[0]))
plt.show()

# %%
print (target[2002])
plt.imshow((input_[2002]))
plt.show()
# Out:
# 35

# %%
print (target[2004])
plt.imshow((input_[2004]))
plt.show()
# Out:
# 26

# %%
print (target[3004])
plt.imshow((input_[3004]))
plt.show()
# Out:
# 34

# %%
print (target[3501])
plt.imshow((input_[3501]))
plt.show()
# Out:
# 45

# %%
print (target[3500])
plt.imshow((input_[3500]))
plt.show()
# Out:
# 45

# %%
plt.imshow((input_[3500]))

# %%
#input_data = np.zeros(shape=(len(input_),480,640,1), dtype = int)

# %%
pkl.dump(input_[2000:], open(r'C:\Users\abelp\machine_learning\crowd_count\final_data\augmented_frames1.pkl', 'wb'))
pkl.dump(target[2000:], open(r'C:\Users\abelp\machine_learning\crowd_count\final_data\augmented_target1.pkl', 'wb'))

# %%
len(input_[2000:])
# Out:
# 2000
