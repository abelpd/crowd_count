# %%
from skimage.color import rgb2hsv
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os
import pickle as pkl
import cv2

# %%
os.getcwd()
# Out:
# 'C:\\Users\\abelp\\machine_learning\\crowd_count'

# %%
cwd = os.getcwd()

# %%
os.listdir(cwd+ '\\data')
# Out:
# ['count_.csv', 'final_input_aj_1.pkl', 'final_input_aj_2.pkl']

# %%
target = pd.read_csv(cwd + '\\data\\count_.csv', names=['target'])

# %%
target
# Out:
#       target
# 0         29
# 1         30
# 2         35
# 3         31
# 4         26
# ...      ...
# 1995      27
# 1996      27
# 1997      25
# 1998      26
# 1999      26
#
# [2000 rows x 1 columns]

# %%
sns.distplot(target['target'])
plt.show()

# %%
input_ = pkl.load( open( cwd+ '\\data\\final_input_aj_1.pkl', "rb" ) )

# %%
input_ = np.append(input_, pkl.load( open( cwd+ '\\data\\final_input_aj_2.pkl', "rb" ) ), axis=0)

# %%
input_.shape
# Out:
# (2000, 480, 640)

# %%
plt.imshow(input_[0])

# %%
datagen = ImageDataGenerator(
        horizontal_flip=True,
        vertical_flip=True,
        fill_mode='nearest')

# %%
target_ = np.array(target['target'])

# %%
target_
# Out:
# array([29, 30, 35, ..., 25, 26, 26], dtype=int64)

# %%
test = input_[0:20]

# %%
test.shape
# Out:
# (20, 480, 640)

# %%
test = np.expand_dims(input_[0:20], axis=3)

# %%
testtarget_ = np.expand_dims(target_[0:20], axis=1)

# %%
testtarget_.shape
# Out:
# (20, 1)

# %%
test.shape
# Out:
# (20, 480, 640, 1)

# %%
datagen.fit(test)

# %%
generated_images_ = datagen.flow(test, y=testtarget_, batch_size=20)

# %%
generated_images_[0][0][0][:,:,0].shape
# Out:
# (480, 640)

# %%
plt.imshow(generated_images_[0][0][0][:,:,0])
plt.show()
print (generated_images_[0][1][0])
# Out:
# [35]

# %%
plt.imshow(generated_images_[0][0][2][:,:,0])
plt.show()
print (generated_images_[0][1][2])
# Out:
# [30]

# %%
for x in range(0,100):
    datagen.fit(input_[x*20:x*20+20])
    generated_images_ = datagen.flow(input_[x*20:x*20+20], y=target[x*20:x*20+20], batch_size=20)
    input_ = np.append(input_, generated_images_[0][0].astype(np.uint8), axis=0)
    target = np.append(target, generated_images_[0][1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-09a5fa625832> in <module>
#       1 for x in range(0,100):
# ----> 2     datagen.fit(input_[x*20:x*20+20])
#       3     generated_images_ = datagen.flow(input_[x*20:x*20+20], y=target[x*20:x*20+20], batch_size=20)
#       4     input_ = np.append(input_, generated_images_[0][0].astype(np.uint8), axis=0)
#       5     target = np.append(target, generated_images_[0][1])
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras_preprocessing\image\image_data_generator.py in fit(self, x, augment, rounds, seed)
#     927         if x.ndim != 4:
#     928             raise ValueError('Input to `.fit()` should have rank 4. '
# --> 929                              'Got array with shape: ' + str(x.shape))
#     930         if x.shape[self.channel_axis] not in {1, 3, 4}:
#     931             warnings.warn(
#
# ...

# %%
input_.shape
# Out:
# (4000, 480, 640, 3)

# %%
len(input_)
# Out:
# 4000

# %%
target.shape
# Out:
# (4000,)

# %%
plt.imshow((images_[2250]))
plt.show()

# %%
input_data = np.zeros(shape=(len(images_),480,640,3), dtype = int)

# %%
# %%time
for x in range(0,len(images_)):
    input_data[x] = cv2.cvtColor(images_[x], cv2.COLOR_BGR2HSV)
# Out:
# Wall time: 1min 27s

# %%
plt.imshow(input_data[2000])
plt.show()

# %%
print("%d bytes" % (input_data.size * input_data.itemsize))
# Out:
# 14745600000 bytes

# %%
input_data[:,:,:,2].size
# Out:
# 1228800000

# %%
inputlayer_ = input_data[:,:,:,2]

# %%
np.save('input_data.npy', inputlayer_)
np.save('target.npy', target)
